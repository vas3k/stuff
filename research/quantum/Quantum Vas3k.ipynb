# %%
from qiskit import QuantumCircuit, assemble, Aer
from qiskit.visualization import plot_histogram, plot_bloch_multivector

# %matplotlib inline

# %%
qc = QuantumCircuit(2, 2)

qc.h(0)
qc.cnot(0, 1)

qc.measure(0, 0)
qc.measure(1, 1)

qc.draw(output='mpl')

# %%
sim = Aer.get_backend('qasm_simulator')
job = assemble(qc)
result = sim.run(job).result()
plot_histogram(result.get_counts())

# %%
sim = Aer.get_backend('statevector_simulator')
job = assemble(qc)
result = sim.run(job).result()
final_state = result.get_statevector(0)    
plot_bloch_multivector(final_state)

# %%
sim = Aer.get_backend('statevector_simulator')
result = sim.run(assemble(qc)).result()
if "11" in result.get_counts():
    print("РЕШКА")
else:
    print("ОРЁЛ")
# Out:
# ОРЁЛ

# %%
from math import pi
from qiskit import IBMQ
IBMQ.save_account("ee3e3f8969225f7b9d87fc1b991a3372a635906f601fa2d2fe62d6be22093936d7b2c4783c24ee6d1ede47659ee0dcc923c0e75ede26de77236c6b4b11c1b50b", overwrite=True)

qc = QuantumCircuit(2, 2)

# real IBM computers do not support pure H gate
# we replace it with RZ+SX+RZ because it's basically the same in our case
qc.rz(pi/2, 0)
qc.sx(0)
qc.rz(pi/2, 0)

qc.cnot(0, 1)

qc.measure(0, 0)
qc.measure(1, 1)

provider = IBMQ.load_account()
qpu = provider.get_backend("ibmq_quito")
result = qpu.run(assemble(qc)).result()
plot_histogram(result.get_counts())
# Out:
# ibmqfactory.load_account:WARNING:2021-03-06 18:29:33,754: Credentials are already in use. The existing account in the session will be replaced.
# <ipython-input-8-e6cad8415eea>:20: DeprecationWarning: Passing a Qobj to Backend.run is deprecated and will be removed in a future release. Please pass in circuits or pulse schedules instead.
#   result = qpu.run(assemble(qc)).result()
